# %% [markdown]
# (github)=
# # Github
#
# Automatic dataset creation for NHANES Surveys: 1988-2000
# - nhanes_fena
# - yearly_cpi
# - table1_fena
# - survplot_fena
#
# Other resources
# - https://projectfena.com/
